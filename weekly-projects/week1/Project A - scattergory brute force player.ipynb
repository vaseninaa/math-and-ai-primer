# %%
# Homework 1 (due 6/28/2024)

# %% [markdown]
# * 1. I tried to API into OpenAI to use ChatGPT to generate answers but I couldn't figure how to properly do that and encountered a bunch of errors. Without LLM, the simplest solution is to write up a list of items starting with letters A-Z for each category and sieve through it. I didn't actually do it myself, but asked ChatGPT to generate the lists. I double-checked them and inserted missing information. Sometimes it skips a letter or gives a dubious answer.
# * 2. I am not sure if one can use OpenAI API for free anymore. According to OpenAI forums, they removed free credits this year and [you have to pay subscription for API](https://community.openai.com/t/does-chatgpt-still-giving-free-18-credits-for-new-users/291019). I would love to learn more about it but it felt not worth it for this little project.
# * 3. In certain categories, there is no item starting with X or Q.

# %%
# Predefined lists of items for each category
category_items = {
    "Fruits": [ "Apple", "Apricot", "Avocado", "Banana", "Blueberry", "Cherry", "Cantaloupe", "Date", "Dragonfruit", "Elderberry", "Fig", "Grape", "Guava", "Honeydew melon", 
               "Ivy gourd", "Jackfruit", "Kiwi", "Kumquat", "Lemon", "Lime", "Mango", "Melon", "Nectarine", "Orange", "Papaya", "Peach", "Pear", "Pineapple", "Plum", "Quince",
               "Raspberry", "Strawberry", "Tangerine", "Ugli fruit", "Vanilla bean", "Watermelon", "Xigua", "Yuzu", "Zalzalak"],
    "Vegetables": ["Artichoke", "Asparagus", "Arugula", "Broccoli", "Brussels sprouts", "Beetroot", "Carrot", "Cauliflower", "Celery", "Daikon", "Dandelion greens", "Eggplant", 
                   "Endive", "Fennel", "Fiddlehead ferns", "Garlic", "Ginger", "Horseradish", "Iceberg lettuce", "Jicama", "Kale", "Kohlrabi", "Leek", "Lettuce", "Mushroom", 
                   "Napa cabbage", "Okra", "Potato", "Pumpkin", "Pea", "Quince", "Radish", "Spinach", "Squash", "Sweet potato", "Tomato", "Turnip", "Ulluco", "Vine spinach", 
                   "Watercress", "Water chestnut", "Yam", "Zucchini"],
    "Animals": ["Antelope", "Bear", "Cat", "Dog", "Elephant", "Fox", "Giraffe", "Horse", "Iguana", "Jaguar", "Kangaroo", "Lion", "Monkey", "Nightingale", "Ostrich", "Penguin", "Quokka",
                "Rabbit", "Squirrel", "Tiger", "Umbrellabird", "Vulture", "Whale", "Xerus (African ground squirrel)", "Yak", "Zebra"],
    "Countries": ["Australia", "Brazil", "Canada", "Denmark", "Egypt", "France", "Germany", "Hungary", "Italy", "Japan", "Kenya", "Libya", "Mexico", "Norway", "Oman",
                  "Portugal", "Qatar", "Russia", "Spain", "Sweden", "Switzerland", "Turkey", "Ukraine", "Vietnam", "Wales", "Yemen", "Zimbabwe"],
    "Cities": ["Athens", "Berlin", "Chicago", "Dubai", "Edinburgh", "Florence", "Geneva", "Helsinki", "Istanbul", "Jerusalem", "Kyoto", "London", "Madrid", "New York", 
               "Oslo", "Paris", "Quincy", "Rome", "Shanghai", "Tokyo", "Utrecht", "Venice", "Warsaw", "Xi'an", "Yokohama", "Zurich"],
    "Famous People": ["Albert Einstein", "Beyoncé", "Charlie Chaplin", "Diana Ross", "Elvis Presley", "Frida Kahlo", "George Clooney", "Helen Keller", "Isaac Newton", 
                      "John Lennon", "Kylie Jenner", "Leonardo da Vinci", "Madonna", "Nelson Mandela", "Oprah Winfrey", "Pablo Picasso", "Queen Elizabeth II", "Rihanna", 
                      "Stephen Hawking", "Taylor Swift", "Usain Bolt", "Vincent van Gogh", "Wolfgang Amadeus Mozart", "Xi Jinping", "Yuri Gagarin", "Zinedine Zidane"],
    "Colors": ["Azure", "Blue", "Crimson", "Daffodil", "Emerald", "Fuchsia", "Gold", "Hazel", "Indigo", "Jade", "Khaki", "Lavender", "Magenta", "Navy blue", "Olive", 
               "Pink", "Purple", "Quartz", "Red", "Saffron", "Turquoise", "Ultramarine", "Violet", "White", "Xanthic", "Yellow", "Zaffre"],
    "Sports": ["Archery", "Baseball", "Cricket", "Diving", "Equestrianism", "Football", "Golf", "Hockey", "Ice skating", "Judo", "Karate", "Lacrosse", 
               "Mountain biking", "Netball", "Orienteering", "Polo", "Quadrathlon", "Rugby", "Soccer", "Tennis", "Ultimate Frisbee", "Volleyball", "Wrestling", "Xare", 
               "Yachting", "Ziplining"],
    "Clothing": ["Anorak", "Blouse", "Coat", "Dress", "Earmuffs", "Frock", "Gloves", "Hat", "Jeans", "Kimono", "Lingerie", "Mittens", "Overalls", "Parka", 
                "Quilted jacket", "Robe", "Scarf", "Shoes", "Trousers", "Uniform", "Vest", "Waistcoat", "Yoga pants", "Zipper"],
    "Food": ["Apple pie", "Bagel", "Cheese", "Donut", "Eggs", "Fries", "Gnocchi", "Hamburger", "Ice cream", "Jam", "Kale", "Lemon", "Milk", "Noodles", "Oatmeal", "Pasta", 
             "Quinoa", "Rice", "Salad", "Tomato", "Udon noodles", "Vegetables", "Waffle", "Yogurt", "Zoodles"],
    "Drinks": ["Ale", "Beer", "Coffee", "Daiquiri", "Espresso", "Fruit juice", "Gin", "Hot chocolate", "Iced tea", "Juice", "Kombucha", "Lemonade", "Margarita", "Negroni", 
               "Orange juice", "Punch", "Rum", "Soda", "Tea", "Umeshu (plum wine)", "Vodka", "Whiskey", "Xocolatl (Aztec chocolate drink)", "Yerba mate", "Zombie (cocktail)"],
    "Tools": ["Axe", "Brush", "Chisel", "Drill", "Extension cord", "File", "Gloves", "Hammer", "Inclinometer", "Jackhammer", "Knife", "Level", "Mallet", "Nail gun", 
              "Oscillating tool", "Pliers", "Quill", "Ratchet", "Saw", "Screwdriver", "Tape measure", "Utility knife", "Vise", "Wrench", "X-acto knife", "Yardstick", "Zip tie"],
    "Flowers": ["Amaryllis", "Begonia", "Carnation", "Daffodil", "Eustoma", "Freesia", "Gardenia", "Hibiscus", "Iris", "Jasmine", "Kalanchoe", "Lavender", "Magnolia", 
                "Narcissus", "Orchid", "Peony", "Queen Anne's lace", "Rose", "Sunflower", "Tulip", "Ursinia", "Violet", "Wisteria", "Xeranthemum", "Yarrow", "Zinnia"],
    "Movies": ["Argo", "Braveheart", "Casablanca", "Django Unchained", "E.T. the Extra-Terrestrial", "Frozen", "Gladiator", "Harry Potter and the Philosopher's Stone", 
               "Inception", "Jurassic Park", "Kill Bill", "La La Land", "Matrix", "No Country for Old Men", "Ocean's Eleven", "Pulp Fiction", "Queen", 
               "Raiders of the Lost Ark", "Shawshank Redemption", "Titanic", "Up", "Vertigo", "Whiplash", "X-Men", "Yojimbo", "Zootopia"],
    "Books": ["Alice's Adventures in Wonderland", "Brave New World", "Catch-22", "Dune", "Ender's Game", "Fahrenheit 451", "Gone with the Wind", 
              "Harry Potter and the Sorcerer's Stone", "It", "Jane Eyre", "Kafka on the Shore", "Les Misérables", "Moby-Dick", "Nation", "Pride and Prejudice", 
              "The Quiet American", "Romeo and Juliet", "Siddhartha", "To Kill a Mockingbird", "Ulysses", "The Velveteen Rabbit", "War and Peace", "Xenocide", 
              "Y: The Last Man", "Zorba the Greek"],
    "Songs": ["All of Me", "Bohemian Rhapsody", "Creep", "Don't Stop Believin'", "Every Breath You Take", "Firework", "Good Vibrations", "Hotel California", 
             "Imagine", "Jolene", "Kiss from a Rose", "Let It Be", "Mamma Mia", "No Woman, No Cry", "Oops!... I Did It Again", "Purple Rain", "Rolling in the Deep", 
             "Stairway to Heaven", "Thriller", "Uptown Funk", "Viva la Vida", "Waterloo", "XO", "Yellow Submarine", "Ziggy Stardust"],
    "TV Shows": ["Arrow", "Breaking Bad", "Chernobyl", "Daredevil", "Euphoria", "Friends", "Game of Thrones", "House MD", "It's Always Sunny in Philadelphia", 
                 "Jessica Jones", "Killing Eve", "Lost", "Money Heist", "Narcos", "The Office", "Parks and Recreation", "Queer Eye", "Stranger Things", 
                 "The Umbrella Academy", "Veep", "The Walking Dead", "X-Files", "You", "Z Nation"],
    "Brands": ["Apple", "Bose", "Coca-Cola", "Disney", "Elle", "Ferrari", "Google", "H&M", "IKEA", "Jaguar", "Kellogg's", "L'Oréal", "Mercedes-Benz", "Nike", "Oreo", 
               "Pepsi", "Qatar Airways", "Rolex", "Samsung", "Tesla", "Under Armour", "Volkswagen", "Walmart", "Xbox", "Yamaha", "Zara"],
    "Transport": ["Airplane", "Bicycle", "Car", "Dolphin boat", "Electric scooter", "Ferry", "Glider", "Helicopter", "Icebreaker", "Jet ski", "Kayak", "Limo", "Motorcycle", 
                  "Narrowboat", "Oar-powered boat", "Pedal boat", "Quad bike", "Rowboat", "Submarine", "Train", "Unicycle", "Van", "Windsurfing board", "X-15 rocket plane", 
                  "Yacht", "Zeppelin"],
    "Jobs": ["Actor", "Barista", "Chef", "Dancer", "Engineer", "Firefighter", "Graphic designer", "Hairdresser", "IT specialist", "Journalist", "Lawyer", "Musician", 
             "Nurse", "Optometrist", "Pilot", "Quarantine officer", "Radiologist", "Scientist", "Teacher", "Undertaker", "Veterinarian", "Waiter", "X-ray technician", 
             "Yoga instructor", "Zookeeper"]
}

# %%
import random

# %%
categories = [
    "Fruits",
    "Vegetables",
    "Animals",
    "Countries",
    "Cities",
    "Famous People",
    "Colors",
    "Sports",
    "Clothing",
    "Food",
    "Drinks",
    "Tools",
    "Flowers",
    "Movies",
    "Books",
    "Songs",
    "TV Shows",
    "Brands",
    "Transport",
    "Jobs"
]

def get_categories():
    print("Here are the available categories:")
    for i, category in enumerate(categories, 1):
        print(f"{i}. {category}")
    
    selected_categories = []
    while len(selected_categories) < 5:
        try:
            choice = int(input(f"Select category {len(selected_categories) + 1} (1-20): "))
            if 1 <= choice <= 20 and categories[choice - 1] not in selected_categories:
                selected_categories.append(categories[choice - 1])
            else:
                print("Invalid choice or category already selected.")
        except ValueError:
            print("Please enter a number between 1 and 20.")
    
    return selected_categories


def generate_answers(selected_categories, letter):
    generated_answers = []
    print(letter)
    print(selected_categories)
    for category in selected_categories:
        for word in category_items[category]:
            if str(word)[0] == str.upper(letter):
                generated_answers.append(word)

    return generated_answers

def scattergories():
    print("Welcome to Scattergories!")
    selected_categories = get_categories()
    letter = input("Enter a letter (A-Z): ").strip().upper()

    
    if letter.isalpha() and len(letter) == 1:
        generated_answers = generate_answers(selected_categories, letter)
        print("\nGenerated Answers:")
        print(generated_answers)
    else:
        print("Invalid letter. Please enter a single letter from A to Z.")

# %%
scattergories()
# Out:
# Welcome to Scattergories!
# Here are the available categories:
# 1. Fruits
# 2. Vegetables
# 3. Animals
# 4. Countries
# 5. Cities
# 6. Famous People
# 7. Colors
# 8. Sports
# 9. Clothing
# 10. Food
# 11. Drinks
# 12. Tools
# 13. Flowers
# 14. Movies
# 15. Books
# 16. Songs
# 17. TV Shows
# 18. Brands
# 19. Transport
# 20. Jobs
# K
# ['Vegetables', 'Flowers', 'Movies', 'Countries', 'Colors']
#
# Generated Answers:
# ['Kale', 'Kohlrabi', 'Kalanchoe', 'Kill Bill', 'Kenya', 'Khaki']
